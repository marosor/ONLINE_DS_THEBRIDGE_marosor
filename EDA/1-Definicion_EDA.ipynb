# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "¿Para quién se programan los festivales de Barcelona?"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Evolución de la relación entre la oferta de fiestas y festivales culturales y el volumen de población local y turistas en Barcelona en la última década""

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "Hay una correlación entre la evolución de las fiestas y festivales que se progaman en Barcelona y el volumen de turismo que llega a la ciudad"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "Se sigue programando para el público local, pero cada vez más se programa también para el turismo"
hipotesis_3 = "Los macrofetsivales se han transformado en un nuevo reclamo publicitario de Barcelona para atraer turistas extranjeros"
hipotesis_4 = "El ritmo de crecimiento de la oferta de fiestas y festivales para extranjeros crece a ritmo más rápido que la oferta para público local o turismo interno"
hipotesis_5 = "Han surgido un número de iniciativas privadas en el ámbito de los fetsivales orientadas a captar turismo internacional"
hipotesis_5 = "La diversificación de la oferta festivalera de Barcelona se orienta especialmente hacia el público angloparlante"

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_1 = pd.read_csv("./data/2022_festivals-assistents-order-name.csv")
fuente_1 = "https://opendata-ajuntament.barcelona.cat/data/es/dataset/dades-festivals/resource/c573360d-ed5d-4609-aaa5-55bb9e9175ca#additional-info"
df_2 = pd.read_csv("./data/2022_dadesciutat-dadesglobals.csv")
fuente_2 = "https://opendata-ajuntament.barcelona.cat/data/es/dataset/dades-globals-cultura/resource/af8bced2-274f-4263-a54e-c37e2741d09d"
df_3 = pd.read_csv("./data/2022_festes-festesciutat-order-name.csv")
fuente_3 = "https://opendata-ajuntament.barcelona.cat/data/es/dataset/dades-festes-ciutat/resource/0d3f939b-72f5-42fe-bb8e-70acfd1f65cf"
# El proyecto incluye 30 datasets, compuesto de los 3 mencionados, y otros 9 equivalentes a esos mismos pero de otros años para abarcar una década entera
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_1.head()
# Out:
#     Any            Ambit              Titularitat      Tipus  Edicio  \
# 0  2022           Música  Ajuntament de Barcelona  Festivals    20.0
# 1  2022          Lletres  Ajuntament de Barcelona  Festivals     2.0
# 2  2022     Arts visuals      Titularitat privada  Festivals    13.0
# 3  2022  Arts escèniques      Titularitat privada  Festivals     6.0
# 4  2022     Audiovisuals      Titularitat privada  Festivals     8.0
#
#                                     NomDelFestival   DataInici      DataFi  \
# 0   (In)fusión Flamenca. Cicle de Flamenc al Besòs   4/11/2022  30/11/2022
# 1  42. Festival de Gèneres Fantàstics de Barcelona   2/11/2022   6/11/2022
# 2                               48H Open House BCN  22/10/2022  23/10/2022
# 3                                    Africa Moment  21/11/2022  24/12/2022
# 4                              Americana Film Fest   15/3/2022   27/3/2022
#
#    Assistents_a_Barcelona  Assistents_fora_de_Barcelona  \
# ...

# %%
# Segundo dataset
df_2.head()
# Out:
#     Any         Categoria                                          Indicador  \
# 0  2022  Dades de context                 Població de la ciutat de Barcelona
# 1  2022  Dades de context      Població de l'Àrea Metropolitana de Barcelona
# 2  2022  Dades de context  % població amb estudis universitaris o cicles ...
# 3  2022  Dades de context  % del pressupost inicial de l'Ajuntament de Ba...
# 4  2022  Dades de context  Renda Disponible de les Llars per càpita (RDL ...
#
#        Valor        Nota                                               Font
# 0  1.636.193         NaN  Font: Oficina Municipal de Dades. Ajuntament d...
# 1  3.304.275         NaN  Font: Oficina Municipal de Dades. Ajuntament d...
# 2       33,4  Dada 2020.  Font: Oficina Municipal de Dades. Ajuntament d...
# 3       6,48         NaN  Font: Institut de Cultura. Ajuntament de Barce...
# 4     20.667  Dada 2020.  Font: Oficina Municipal de Dades. Ajuntament d...

# %%
# Tercer dataset
df_3.head()
# Out:
#     Any                Ambit              Titularitat   Tipus  Edicio  \
# 0  2022  Festes i tradicions                    Mixta  Festes     NaN
# 1  2022  Festes i tradicions  Ajuntament de Barcelona  Festes     NaN
# 2  2022  Festes i tradicions                    Mixta  Festes     NaN
# 3  2022  Festes i tradicions                    Mixta  Festes     NaN
# 4  2022  Festes i tradicions  Ajuntament de Barcelona  Festes     NaN
#
#                          Festa   DataInici      DataFi  Assistents  \
# 0                     Carnaval   24/2/2022    2/3/2022         NaN
# 1            Cavalcada de Reis    5/1/2022    5/1/2022    425000.0
# 2  Diada de l'Onze de Setembre   11/9/2022   11/9/2022         NaN
# 3          Diada de Sant Jordi   23/4/2022   23/4/2022         NaN
# 4  Espectacle Nit de Cap d'Any  31/12/2022  31/12/2022    120000.0
#
#                                  Espai  \
# 0         Diversos espais de la ciutat
# 1         Diversos espais de la ciutat
# ...
